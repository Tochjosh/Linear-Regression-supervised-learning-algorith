# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# plt.rcParams['figure.figuresize'] = (20.0, 10.0)

#reloading data
data = pd.read_csv('/Users/decagon/desktop/students - students.csv')
print(data.shape)
# Out:
# (20, 6)

# %%
data.head(25)
# Out:
#                 name  age       sport  Biology_score  Maths_score  \
# 0   Emmanuel Ayomide   27    Football           73.0         58.0
# 1       Ibrahim Musa   24    Football           92.0         56.0
# 2          Sesan Obi   24    Swimming           67.0         95.0
# 3        Kevin Frank   25      Tennis           53.0         85.0
# 4         Emeka Jude   24  Basketball           86.0         80.0
# 5       Caroline Obi   27  Basketball           92.0         71.0
# 6   Franklin Oladele   18    Football           96.0          NaN
# 7           Kola Ola   28    Swimming           82.0         95.0
# 8       Emmanuel Ovi   23      Tennis           79.0         61.0
# 9        Kareem Musa   24    Football           78.0         73.0
# 10    Mustapha Ahmed   24         NaN           88.0         84.0
# 11         Femi Akin   24      Tennis           90.0         97.0
# 12     Tobi Olaniyan   22  Volleyball           51.0         79.0
# ...

# %%
data.isnull().sum()
# Out:
# name             0
# age              0
# sport            1
# Biology_score    1
# Maths_score      1
# English_score    1
# dtype: int64

# %%
data.dropna(inplace=True)

# %%
data.head(25)
# Out:
#                 name  age       sport  Biology_score  Maths_score  \
# 0   Emmanuel Ayomide   27    Football           73.0         58.0
# 1       Ibrahim Musa   24    Football           92.0         56.0
# 2          Sesan Obi   24    Swimming           67.0         95.0
# 3        Kevin Frank   25      Tennis           53.0         85.0
# 4         Emeka Jude   24  Basketball           86.0         80.0
# 5       Caroline Obi   27  Basketball           92.0         71.0
# 7           Kola Ola   28    Swimming           82.0         95.0
# 8       Emmanuel Ovi   23      Tennis           79.0         61.0
# 9        Kareem Musa   24    Football           78.0         73.0
# 11         Femi Akin   24      Tennis           90.0         97.0
# 12     Tobi Olaniyan   22  Volleyball           51.0         79.0
# 13    Kayode Ibrahim   25    Football           58.0         67.0
# 15        Ahmed Musa   24    Football           60.0         90.0
# ...

# %%
sns.countplot(x='age', data=data)
# Out:
# <AxesSubplot:xlabel='age', ylabel='count'>

# %%
X = data['age'].values
Y = data['Maths_score'].values

# %%
mean_x = np.mean(X)
mean_y = np.mean(Y)

#number of values
n = len(X)

#use formular to calculate b1 and b0
numerator = 0
denominator = 0

for i in range(n):
    numerator += ((X[i] - mean_x) * (Y[i] - mean_y))
    denominator += (X[i] - mean_x) ** 2

b1 = numerator / denominator
b0 = mean_y - (b1 * mean_x)

#print coefficients
print(b1, b0)
# Out:
# 0.13362068965517254 76.13793103448275

# %%
# plotting values
max_x = np.max(X) + 100
min_x = np.min(X)

# claculating line values of x and y
x = np.linspace(min_x, max_x, 1000)
y = b0 + b1 * x

#plotting line
plt.plot(x, y, label='Regression Line')

plt.scatter(x, y, label='Scatter Plot')

plt.xlabel('Age')
plt.ylabel('maths Score')

plt.legend()
plt.show()

# %%
ss_t = 0
ss_r = 0
for i in range(n):
    y_pred = b0 + b1 * X[i]
    ss_t += (Y[i] - mean_y) ** 2
    ss_r += (Y[i] - y_pred) ** 2
r2 = 1 - (ss_r/ss_t)
print(r2)
# Out:
# 0.00023014156859646473
